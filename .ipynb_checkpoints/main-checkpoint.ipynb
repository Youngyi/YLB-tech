# %% [markdown]
# 加载数据

# %%
import para
import csv
import numpy as np

# print(t)
for i in range(para.machine_num):
    file_path = para.train_data +  "{0:03d}".format(i+1) + '/201807.csv'
    with open(file_path,'r') as file:
        data = csv.reader(file)
        data.__next__()
        full_data = []
        miss_data = []
        for record in data:
            if any([r==''for r in record]):
                miss_data.append(record)
            else:
                full_data.append(record)
        raw_data_str = full_data#np.array(full_data,dtype = {(n,d) for n,d in zip(para.attrs,t)})
#     data = np.loadtxt(file_path,delimiter=',',skiprows= 1,dtype = np.str)
#     print(data[0],data.shape,data.dtype)
    
    break

# %% [markdown]
# 无缺失字段记录

# %%
t = ['M'] + ['i4'] + ['f4']*15+['i4']+['f4']*3+['i4']+['f4']*26+['i4']+['f4']*5+['i4']+['f4']*12+['i4']+['f4']*2

raw_data_str = np.array(raw_data_str)
raw_data = []
import matplotlib.pyplot as plt
for i in range(70):
    s = raw_data_str[:,i].astype(t[i])
    if i != 0 and i !=1:
        plt.figure()
        plt.hist(s)
        plt.xlabel('var num {0}, type {5}, min {1:.2f}, max {2:.2f}, mean {3:.2f}, std {4:.2f}'.format(i+1,np.min(s),np.max(s),np.mean(s),np.std(s),t[i]))
        plt.show()
    raw_data.append(s)
#     print(s[0],s.dtype)

# print(raw_data[0],raw_data.dtype)

# %% [markdown]
# 有缺失字段记录

# %%
miss_count = [0 for _ in range(70)]
miss_total = len(miss_data)
print(miss_total)
for r in miss_data:
    for i in range(len(r)):
        if r[i]=='':
            miss_count[i]+=1
miss_count = np.array(miss_count)
plt.figure(figsize=(16,8))
plt.bar(np.array(range(70)),miss_count/miss_total)
plt.show()
# Out:
# 5675
